# %%
#f = open('/home/shashank/workspace/Statistics_and_Machine_Learning/Statistics-and-Machine-Learning/trainingAndTest/training-and-test/training.json', "r")

# %% [markdown]
# strip is used to reme white spaces like '\n'
# split is used to convert it into list

# %%
# import json
# data={}
# students=0
# count=0
# for i in f:
#     if count==0:
#         students=int(i.strip())
#         count+=1
#     else:
#         data[json.loads(i.strip())['serial']]=json.loads(i.strip())  
#         count+=1

# %%
import pandas as pd
df=pd.DataFrame(data)

# %%
#df.to_csv('school_data.csv')

# %%
df.T.corr()
# Out:
#                    Accountancy   Biology  BusinessStudies  Chemistry  \
# Accountancy           1.000000       NaN         0.649718   0.614151
# Biology                    NaN  1.000000              NaN   0.678521
# BusinessStudies       0.649718       NaN         1.000000   0.000000
# Chemistry             0.614151  0.678521         0.000000   1.000000
# ComputerScience       0.445796       NaN         0.548860   0.679314
# Economics             0.679753       NaN         0.657774   0.668026
# English               0.502118  0.466226         0.591130   0.454287
# Mathematics           0.684171  0.574887         0.604873   0.719888
# PhysicalEducation     0.447006  0.197489         0.394378   0.429793
# Physics               0.815446  0.694336         0.470777   0.769097
# serial                0.022595 -0.001295         0.012560  -0.007622
#
#                    ComputerScience  Economics   English  Mathematics  \
# ...

# %%
df.T.drop("serial")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-6dbc9208115c> in <module>()
# ----> 1 df.T.drop("serial")
#
# /home/shashank/.local/lib/python2.7/site-packages/pandas/core/frame.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3938                                            index=index, columns=columns,
#    3939                                            level=level, inplace=inplace,
# -> 3940                                            errors=errors)
#    3941
#    3942     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /home/shashank/.local/lib/python2.7/site-packages/pandas/core/generic.pyc in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3778         for axis, labels in axes.items():
#    3779             if labels is not None:
# ...
